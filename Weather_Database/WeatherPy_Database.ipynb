# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations 
lats = np.random.uniform(90.000, -90.000, size = 2000)
lngs = np.random.uniform(180.000, -180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities= []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city to confirm sufficient count 
len(cities)
# Out:
# 736

# %%
# Importing weather API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Make an API call
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group the cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]

# %%
cities
# Out:
# ['bandarbeyla',
#  'dikson',
#  'goya',
#  'jacareacanga',
#  'rikitea',
#  'louisbourg',
#  'saskylakh',
#  'jumla',
#  'victor harbor',
#  'georgetown',
#  'comodoro rivadavia',
#  'hobart',
#  'saint-philippe',
#  'gorontalo',
#  'ushuaia',
#  'atuona',
#  'albany',
#  'vaini',
#  'altamira',
#  'gasa',
#  'katsuura',
#  'mataura',
#  'avarua',
#  'hermanus',
#  'meyungs',
#  'vila franca do campo',
#  'creel',
#  'jamestown',
#  'mar del plata',
#  'port alfred',
#  'sao fidelis',
#  'tasiilaq',
#  'bensonville',
#  'bluff',
#  'longyearbyen',
#  'price',
#  'abu kamal',
#  'cabedelo',
#  'busselton',
#  'ribeira grande',
#  'punta arenas',
#  'mount pleasant',
#  'hilo',
#  'cape town',
#  'linjiang',
#  'ponta do sol',
#  'barrow',
#  'asau',
#  'kriva palanka',
#  'kaeo',
#  'lensk',
#  'dunedin',
#  'belushya guba',
#  'shelburne',
#  'khatanga',
#  'inderborskiy',
#  'gadsden',
#  'kanniyakumari',
#  'lolua',
#  'yellowknife',
#  'byron bay',
#  'balaipungut',
#  'cardonal',
#  'thompson',
#  'tuktoyaktuk',
#  'chokurdakh',
#  'nizhneyansk',
#  'tabiauea',
#  'lebu',
#  'provideniya',
#  'pevek',
#  'coquimbo',
#  'visby',
#  'new norfolk',
#  'nha trang',
#  'sao joao da ponte',
#  'san quintin',
#  'kloulklubed',
#  'berlevag',
#  'torbay',
#  'mys shmidta',
#  'vostok',
#  'biak',
#  'kavaratti',
#  'matara',
#  'cidreira',
#  'caravelas',
#  'kasongo-lunda',
#  'hamilton',
#  'fortuna',
#  'butaritari',
#  'pyinmana',
#  'illoqqortoormiut',
#  'klaksvik',
#  'samusu',
#  'joshimath',
#  'port elizabeth',
#  'bredasdorp',
#  'touros',
#  'abu dhabi',
#  'talnakh',
#  'kapaa',
#  'bethel',
#  'chapeco',
#  'mount gambier',
#  'buqayq',
#  'bemidji',
#  'taolanaro',
#  'ostrovnoy',
#  'leh',
#  'morant bay',
#  'guerrero negro',
#  'victoria',
#  'kaitangata',
#  'esperance',
#  'yerbogachen',
#  'salgado',
#  'vanimo',
#  'mahebourg',
#  'kutum',
#  'usevya',
#  'tarko-sale',
#  'veraval',
#  'crotone',
#  'north platte',
#  'savonlinna',
#  'norman wells',
#  'maumere',
#  'sentyabrskiy',
#  'toliary',
#  'artyk',
#  'bulgan',
#  'verkhoyansk',
#  'bengkulu',
#  'upernavik',
#  'bitung',
#  'richards bay',
#  'bolshoye sorokino',
#  'airai',
#  'tilichiki',
#  'cayenne',
#  'pisco',
#  'saint george',
#  'rhyl',
#  'micheweni',
#  'gangotri',
#  'sandakan',
#  'dillon',
#  'kununurra',
#  'barentsburg',
#  'pervomayskoye',
#  'indramayu',
#  'gat',
#  'kitimat',
#  'cuxhaven',
#  'kamaishi',
#  'nanortalik',
#  'puerto ayora',
#  'itarema',
#  'egvekinot',
#  'vestmanna',
#  'marabba',
#  'clyde river',
#  'lamar',
#  'ust-kulom',
#  'tototlan',
#  'port hardy',
#  'namibe',
#  'adrar',
#  'marcona',
#  'tiksi',
#  'esil',
#  'makasar',
#  'yablonovo',
#  'cherskiy',
#  'mrirt',
#  'kirakira',
#  'dingle',
#  'avenal',
#  'sakakah',
#  'vaitupu',
#  'hami',
#  'richmond hill',
#  'baykit',
#  'anadyr',
#  'umm durman',
#  'arys',
#  'kandrian',
#  'richmond',
#  'hasaki',
#  'mackay',
#  'husavik',
#  'nagaur',
#  'texarkana',
#  'port augusta',
#  'nemuro',
#  'majene',
#  'mount isa',
#  'port-gentil',
#  'rivadavia',
#  'bloomington',
#  'maicao',
#  'karpathos',
#  'filadelfia',
#  'goderich',
#  'aykhal',
#  'severo-yeniseyskiy',
#  'kruisfontein',
#  'oktyabrskoye',
#  'narsaq',
#  'ahipara',
#  'sabha',
#  'innisfail',
#  'nouadhibou',
#  'jiaocheng',
#  'tromso',
#  'vao',
#  'kot putli',
#  'flinders',
#  'grand river south east',
#  'yashan',
#  'olecko',
#  'purranque',
#  'isangel',
#  'hecun',
#  'verkhnevilyuysk',
#  'sankt polten',
#  'sola',
#  'lavrentiya',
#  'agogo',
#  'souris',
#  'rehoboth',
#  'marawi',
#  'pampa',
#  'lompoc',
#  'castro',
#  'unity',
#  'luderitz',
#  'carnarvon',
#  'arraial do cabo',
#  'geraldton',
#  'peniche',
#  'warrnambool',
#  'oriximina',
#  'zhigansk',
#  'shache',
#  'port macquarie',
#  'shenjiamen',
#  'chowchilla',
#  'grand-lahou',
#  'kahului',
#  'high level',
#  'ostrov',
#  'hue',
#  'sistranda',
#  'peleduy',
#  'bonavista',
#  'ulladulla',
#  'harper',
#  'guarapari',
#  'utiroa',
#  'kamenskoye',
#  'marsa matruh',
#  'puerto quijarro',
#  'kuah',
#  'saldanha',
#  'hambantota',
#  'kyren',
#  'paamiut',
#  'falealupo',
#  'djibo',
#  'ende',
#  'necochea',
#  'winnemucca',
#  'nam tha',
#  'lorengau',
#  'ponta delgada',
#  'amderma',
#  'yulara',
#  'karratha',
#  'lavumisa',
#  'souillac',
#  'lubao',
#  'edd',
#  'samandag',
#  'visnes',
#  'koslan',
#  'qaanaaq',
#  'hervey bay',
#  'tangjiazhuang',
#  'sterling',
#  'pierre',
#  'abadzekhskaya',
#  'nantucket',
#  'severo-kurilsk',
#  'makat',
#  'leningradskiy',
#  'sayyan',
#  'grand gaube',
#  'san pedro',
#  'coahuayana',
#  'whitehorse',
#  'glendive',
#  'cabo san lucas',
#  'torgau',
#  'tuy hoa',
#  'grindavik',
#  'nome',
#  'korla',
#  'junin',
#  'turukhansk',
#  'hofn',
#  'karkaralinsk',
#  'port hawkesbury',
#  'sao filipe',
#  'adamas',
#  'centralia',
#  'chicama',
#  'tchollire',
#  'high prairie',
#  'hollabrunn',
#  'ancud',
#  'olga',
#  'noshiro',
#  'komsomolskiy',
#  'uyemskiy',
#  'katobu',
#  'lebyazhye',
#  'nguru',
#  'umzimvubu',
#  'boa vista',
#  'mackenzie',
#  'vangaindrano',
#  'tyukhtet',
#  'kalabo',
#  'linxia',
#  'anapskaya',
#  'carballo',
#  'inirida',
#  'novoshcherbinovskaya',
#  'sitka',
#  'donskoye',
#  'niteroi',
#  'javornik',
#  'chekhov',
#  'palembang',
#  'nikolskoye',
#  'shingu',
#  'tias',
#  'kavieng',
#  'makung',
#  'sibolga',
#  'iqaluit',
#  'yate',
#  'sorland',
#  'garowe',
#  'babanusah',
#  'tshikapa',
#  'mentok',
#  'morros',
#  'huarmey',
#  'the valley',
#  'alofi',
#  'kuzedeyevo',
#  'karauzyak',
#  'yunjinghong',
#  'namatanai',
#  'srednekolymsk',
#  'hot springs',
#  'trairi',
#  'quebrangulo',
#  'beled',
#  'russell',
#  'pella',
#  'rennes',
#  'saleaula',
#  'nicoya',
#  'ijaki',
#  'tacuarembo',
#  'atambua',
#  'save',
#  'sao gabriel da cachoeira',
#  'bose',
#  'kibondo',
#  'skelleftea',
#  'seymchan',
#  'sfantu gheorghe',
#  'awbari',
#  'mehamn',
#  'xinzhi',
#  'mandalgovi',
#  'chapais',
#  'olinda',
#  'lepe',
#  'sembakung',
#  'coihaique',
#  'hithadhoo',
#  'tual',
#  'lujan',
#  'saint-joseph',
#  'bulawayo',
#  'tura',
#  'rungata',
#  'olden',
#  'tessalit',
#  'east london',
#  'lagoa',
#  'coralville',
#  'aripuana',
#  'salalah',
#  'hashimoto',
#  'kodiak',
#  'harihar',
#  'waipawa',
#  'labuhan',
#  'ngukurr',
#  'huittinen',
#  'hasanpur',
#  'shaowu',
#  'kondinskoye',
#  'cedar city',
#  'barabai',
#  'tadine',
#  'vulcan',
#  'waddan',
#  'nobeoka',
#  'samarai',
#  'papara',
#  'tautira',
#  'culpeper',
#  'codrington',
#  'sekoma',
#  'wawa',
#  'khoy',
#  'saint-leu',
#  'ozernovskiy',
#  'khomeynishahr',
#  'banda aceh',
#  'zalantun',
#  'tuatapere',
#  'acapulco',
#  'halalo',
#  'kupang',
#  'udachnyy',
#  'paramirim',
#  'veinticinco de mayo',
#  'buin',
#  'igarka',
#  'haines junction',
#  'sur',
#  'eganville',
#  'pangnirtung',
#  'bolungarvik',
#  'oros',
#  'port hedland',
#  'bungoma',
#  'ouallam',
#  'smithers',
#  'ishigaki',
#  'mananjary',
#  'eirunepe',
#  'honiara',
#  'teeswater',
#  'vestmannaeyjar',
#  'naftah',
#  'monaragala',
#  'galle',
#  'znamenskoye',
#  'san luis',
#  'faya',
#  'sartell',
#  'sotnikovo',
#  'ilulissat',
#  'zabid',
#  'weyburn',
#  'araouane',
#  'yambio',
#  'severnyy',
#  'daru',
#  'samfya',
#  'mayo',
#  'novikovo',
#  'scarborough',
#  'chuy',
#  'sao joao da barra',
#  'kerchevskiy',
#  'sawakin',
#  'ludwigslust',
#  'morgantown',
#  'constitucion',
#  'potsdam',
#  'vung tau',
#  'polunochnoye',
#  'nautla',
#  'bambous virieux',
#  'amahai',
#  'sedelnikovo',
#  'aasiaat',
#  'bambanglipuro',
#  'saint-esteve',
#  'vilhena',
#  'antsohihy',
#  'onega',
#  'luanda',
#  'kyaikto',
#  'aflu',
#  'fort nelson',
#  'carutapera',
#  'bathsheba',
#  'griffith',
#  'marzuq',
#  'miraflores',
#  'oranjemund',
#  'fujin',
#  'chipinge',
#  'pitimbu',
#  'torit',
#  'safaga',
#  'iralaya',
#  'chepareria',
#  'panama city',
#  'balykshi',
#  'trofors',
#  'imbituba',
#  'port blair',
#  'anloga',
#  'los llanos de aridane',
#  'koroni',
#  'praia',
#  'taltal',
#  'najran',
#  'hovd',
#  'padang',
#  'marsh harbour',
#  'ayan',
#  'snezhnogorsk',
#  'hobyo',
#  'puerto del rosario',
#  'bodden town',
#  'chimbote',
#  'lubango',
#  'alta floresta',
#  'tsihombe',
#  'kiunga',
#  'angoche',
#  'skalistyy',
#  'brae',
#  'ixtapa',
#  'zaterechnyy',
#  'north bend',
#  'nuuk',
#  'demba',
#  'mulege',
#  'arkhara',
#  'labutta',
#  'havre-saint-pierre',
#  'pyaozerskiy',
#  'puerto escondido',
#  'buchanan',
#  'enid',
#  'hohhot',
#  'ekibastuz',
#  'oussouye',
#  'escanaba',
#  'solovetskiy',
#  'durango',
#  'dekoa',
#  'meadow lake',
#  'north battleford',
#  'sinnamary',
#  'saint anthony',
#  'curumani',
#  'jijiang',
#  'charters towers',
#  'fairbanks',
#  'tawkar',
#  'saint-pierre',
#  'zhireken',
#  'khandbari',
#  'west wendover',
#  'singapore',
#  'cairns',
#  'belyy yar',
#  'jacksonville',
#  'nauta',
#  'maridi',
#  'olafsvik',
#  'makakilo city',
#  'celestun',
#  'seoul',
#  'yar-sale',
#  'kimberley',
#  'teya',
#  'biggar',
#  'gigmoto',
#  'jalu',
#  'surt',
#  'sept-iles',
#  'rudnogorsk',
#  'lerwick',
#  'linhares',
#  'belogorsk',
#  'homer',
#  'fort frances',
#  'mae hong son',
#  'san cristobal',
#  'hala',
#  'tigil',
#  'juneau',
#  'anchorage',
#  'pingliang',
#  'denpasar',
#  'sao sebastiao',
#  'port lincoln',
#  'westport',
#  'lebane',
#  'meulaboh',
#  'cockburn town',
#  'brigantine',
#  'kuusankoski',
#  'kollam',
#  'rudbar',
#  'robat karim',
#  'skjervoy',
#  'lagos',
#  'rio gallegos',
#  'sarahan',
#  'tumannyy',
#  'ghorawal',
#  'fairview',
#  'tandlianwala',
#  'antofagasta',
#  'baghdad',
#  'tawang',
#  'tubmanburg',
#  'lalomanu',
#  'kampot',
#  'luziania',
#  'oneida',
#  'laguna',
#  'krasnotorka',
#  'ilhabela',
#  'kyra',
#  'sao felix do xingu',
#  'attawapiskat',
#  'mandi bahauddin',
#  'chiredzi',
#  'dole',
#  'leon valley',
#  'pouembout',
#  'lindi',
#  'cochrane',
#  'gamba',
#  'vila velha',
#  'zapolyarnyy',
#  'mercedes',
#  'port-cartier',
#  'dharchula',
#  'cody',
#  'vaitape',
#  'sambava',
#  'ketchikan',
#  'vuktyl',
#  'verkhniy avzyan',
#  'pochutla',
#  'bosaso',
#  'sahrak',
#  'birakan',
#  'malartic',
#  'sebu',
#  'bilibino',
#  'brainerd',
#  'evensk',
#  'tigre',
#  'paraiso',
#  'scottsburgh',
#  'chissamba',
#  'asarganj',
#  'pangkalanbuun',
#  'hunza',
#  'ulze',
#  'zhanakorgan',
#  'san policarpo',
#  'umm jarr',
#  'yabelo',
#  'hvammstangi',
#  'acajutla',
#  'erenhot',
#  'flagstaff',
#  'jiazi',
#  'samarkand',
#  'hay river',
#  'springbok',
#  'liverpool',
#  'taldan',
#  'termoli',
#  'yenotayevka',
#  'tarazona',
#  'sao jose da coroa grande',
#  'causapscal',
#  'sioux lookout',
#  'bokajan',
#  'markova',
#  'hongan',
#  'mutata',
#  'correntina',
#  'karaman',
#  'hualmay',
#  'mozarlandia',
#  'ginir',
#  'severomorsk',
#  'mitsamiouli',
#  'sibulan',
#  'talcahuano',
#  'broome',
#  'yuzhno-yeniseyskiy',
#  'mombetsu',
#  'caxito',
#  'lapua',
#  'hinatuan',
#  'crnici',
#  'porto walter',
#  'faanui',
#  'saint-augustin',
#  'chopovychi',
#  'tukrah',
#  'mufumbwe',
#  'myitkyina',
#  'tarudant',
#  'inuvik',
#  'aklavik',
#  'artyom',
#  'corn island',
#  'sucua',
#  'inongo',
#  'inhambane']

# %%
# Loop through all the cities in the list    
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
         # Parse the JSON and retreive data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H-%M-%S")
        
        # Append the city infomration into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description})
        
# If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping...")
        pass
    
# Indicate that Data Loading is Complete
print("--------------------------------")
print("Data Retreival Complete         ")
print("--------------------------------")
# Out:
# Processing Record 1 of Set 15 | bandarbeyla
# Processing Record 2 of Set 15 | dikson
# Processing Record 3 of Set 15 | goya
# Processing Record 4 of Set 15 | jacareacanga
# Processing Record 5 of Set 15 | rikitea
# Processing Record 6 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 15 | saskylakh
# Processing Record 8 of Set 15 | jumla
# Processing Record 9 of Set 15 | victor harbor
# Processing Record 10 of Set 15 | georgetown
# Processing Record 11 of Set 15 | comodoro rivadavia
# Processing Record 12 of Set 15 | hobart
# Processing Record 13 of Set 15 | saint-philippe
# Processing Record 14 of Set 15 | gorontalo
# Processing Record 15 of Set 15 | ushuaia
# Processing Record 16 of Set 15 | atuona
# Processing Record 17 of Set 15 | albany
# Processing Record 18 of Set 15 | vaini
# Processing Record 19 of Set 15 | altamira
# Processing Record 20 of Set 15 | gasa
# Processing Record 21 of Set 15 | katsuura
# Processing Record 22 of Set 15 | mataura
# Processing Record 23 of Set 15 | avarua
# Processing Record 24 of Set 15 | hermanus
# Processing Record 25 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 15 | vila franca do campo
# Processing Record 27 of Set 15 | creel
# Processing Record 28 of Set 15 | jamestown
# Processing Record 29 of Set 15 | mar del plata
# Processing Record 30 of Set 15 | port alfred
# Processing Record 31 of Set 15 | sao fidelis
# Processing Record 32 of Set 15 | tasiilaq
# Processing Record 33 of Set 15 | bensonville
# Processing Record 34 of Set 15 | bluff
# Processing Record 35 of Set 15 | longyearbyen
# Processing Record 36 of Set 15 | price
# Processing Record 37 of Set 15 | abu kamal
# Processing Record 38 of Set 15 | cabedelo
# Processing Record 39 of Set 15 | busselton
# Processing Record 40 of Set 15 | ribeira grande
# Processing Record 41 of Set 15 | punta arenas
# Processing Record 42 of Set 15 | mount pleasant
# Processing Record 43 of Set 15 | hilo
# Processing Record 44 of Set 15 | cape town
# Processing Record 45 of Set 15 | linjiang
# Processing Record 46 of Set 15 | ponta do sol
# Processing Record 47 of Set 15 | barrow
# Processing Record 48 of Set 15 | asau
# Processing Record 49 of Set 15 | kriva palanka
# Processing Record 50 of Set 15 | kaeo
# Processing Record 1 of Set 16 | lensk
# Processing Record 2 of Set 16 | dunedin
# Processing Record 3 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 16 | shelburne
# Processing Record 5 of Set 16 | khatanga
# Processing Record 6 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 16 | gadsden
# Processing Record 8 of Set 16 | kanniyakumari
# Processing Record 9 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 16 | yellowknife
# Processing Record 11 of Set 16 | byron bay
# Processing Record 12 of Set 16 | balaipungut
# Processing Record 13 of Set 16 | cardonal
# Processing Record 14 of Set 16 | thompson
# Processing Record 15 of Set 16 | tuktoyaktuk
# Processing Record 16 of Set 16 | chokurdakh
# Processing Record 17 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 16 | lebu
# Processing Record 20 of Set 16 | provideniya
# Processing Record 21 of Set 16 | pevek
# Processing Record 22 of Set 16 | coquimbo
# Processing Record 23 of Set 16 | visby
# Processing Record 24 of Set 16 | new norfolk
# Processing Record 25 of Set 16 | nha trang
# Processing Record 26 of Set 16 | sao joao da ponte
# Processing Record 27 of Set 16 | san quintin
# Processing Record 28 of Set 16 | kloulklubed
# Processing Record 29 of Set 16 | berlevag
# Processing Record 30 of Set 16 | torbay
# Processing Record 31 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 16 | vostok
# Processing Record 33 of Set 16 | biak
# Processing Record 34 of Set 16 | kavaratti
# Processing Record 35 of Set 16 | matara
# Processing Record 36 of Set 16 | cidreira
# Processing Record 37 of Set 16 | caravelas
# Processing Record 38 of Set 16 | kasongo-lunda
# Processing Record 39 of Set 16 | hamilton
# Processing Record 40 of Set 16 | fortuna
# Processing Record 41 of Set 16 | butaritari
# Processing Record 42 of Set 16 | pyinmana
# Processing Record 43 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 16 | klaksvik
# Processing Record 45 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 16 | joshimath
# Processing Record 47 of Set 16 | port elizabeth
# Processing Record 48 of Set 16 | bredasdorp
# Processing Record 49 of Set 16 | touros
# Processing Record 50 of Set 16 | abu dhabi
# Processing Record 1 of Set 17 | talnakh
# Processing Record 2 of Set 17 | kapaa
# Processing Record 3 of Set 17 | bethel
# Processing Record 4 of Set 17 | chapeco
# Processing Record 5 of Set 17 | mount gambier
# Processing Record 6 of Set 17 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 17 | bemidji
# Processing Record 8 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 17 | ostrovnoy
# Processing Record 10 of Set 17 | leh
# Processing Record 11 of Set 17 | morant bay
# Processing Record 12 of Set 17 | guerrero negro
# Processing Record 13 of Set 17 | victoria
# Processing Record 14 of Set 17 | kaitangata
# Processing Record 15 of Set 17 | esperance
# Processing Record 16 of Set 17 | yerbogachen
# Processing Record 17 of Set 17 | salgado
# Processing Record 18 of Set 17 | vanimo
# Processing Record 19 of Set 17 | mahebourg
# Processing Record 20 of Set 17 | kutum
# Processing Record 21 of Set 17 | usevya
# Processing Record 22 of Set 17 | tarko-sale
# Processing Record 23 of Set 17 | veraval
# Processing Record 24 of Set 17 | crotone
# Processing Record 25 of Set 17 | north platte
# Processing Record 26 of Set 17 | savonlinna
# Processing Record 27 of Set 17 | norman wells
# Processing Record 28 of Set 17 | maumere
# Processing Record 29 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 17 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 17 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 17 | bulgan
# Processing Record 33 of Set 17 | verkhoyansk
# Processing Record 34 of Set 17 | bengkulu
# Processing Record 35 of Set 17 | upernavik
# Processing Record 36 of Set 17 | bitung
# Processing Record 37 of Set 17 | richards bay
# Processing Record 38 of Set 17 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 39 of Set 17 | airai
# Processing Record 40 of Set 17 | tilichiki
# Processing Record 41 of Set 17 | cayenne
# Processing Record 42 of Set 17 | pisco
# Processing Record 43 of Set 17 | saint george
# Processing Record 44 of Set 17 | rhyl
# Processing Record 45 of Set 17 | micheweni
# Processing Record 46 of Set 17 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 17 | sandakan
# Processing Record 48 of Set 17 | dillon
# Processing Record 49 of Set 17 | kununurra
# Processing Record 50 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 18 | pervomayskoye
# Processing Record 2 of Set 18 | indramayu
# Processing Record 3 of Set 18 | gat
# Processing Record 4 of Set 18 | kitimat
# Processing Record 5 of Set 18 | cuxhaven
# Processing Record 6 of Set 18 | kamaishi
# Processing Record 7 of Set 18 | nanortalik
# Processing Record 8 of Set 18 | puerto ayora
# Processing Record 9 of Set 18 | itarema
# Processing Record 10 of Set 18 | egvekinot
# Processing Record 11 of Set 18 | vestmanna
# Processing Record 12 of Set 18 | marabba
# Processing Record 13 of Set 18 | clyde river
# Processing Record 14 of Set 18 | lamar
# Processing Record 15 of Set 18 | ust-kulom
# Processing Record 16 of Set 18 | tototlan
# Processing Record 17 of Set 18 | port hardy
# Processing Record 18 of Set 18 | namibe
# Processing Record 19 of Set 18 | adrar
# Processing Record 20 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 18 | tiksi
# Processing Record 22 of Set 18 | esil
# Processing Record 23 of Set 18 | makasar
# Processing Record 24 of Set 18 | yablonovo
# Processing Record 25 of Set 18 | cherskiy
# Processing Record 26 of Set 18 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 18 | kirakira
# Processing Record 28 of Set 18 | dingle
# Processing Record 29 of Set 18 | avenal
# Processing Record 30 of Set 18 | sakakah
# Processing Record 31 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 18 | hami
# Processing Record 33 of Set 18 | richmond hill
# Processing Record 34 of Set 18 | baykit
# Processing Record 35 of Set 18 | anadyr
# Processing Record 36 of Set 18 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 18 | arys
# Processing Record 38 of Set 18 | kandrian
# Processing Record 39 of Set 18 | richmond
# Processing Record 40 of Set 18 | hasaki
# Processing Record 41 of Set 18 | mackay
# Processing Record 42 of Set 18 | husavik
# Processing Record 43 of Set 18 | nagaur
# Processing Record 44 of Set 18 | texarkana
# Processing Record 45 of Set 18 | port augusta
# Processing Record 46 of Set 18 | nemuro
# Processing Record 47 of Set 18 | majene
# Processing Record 48 of Set 18 | mount isa
# Processing Record 49 of Set 18 | port-gentil
# Processing Record 50 of Set 18 | rivadavia
# Processing Record 1 of Set 19 | bloomington
# Processing Record 2 of Set 19 | maicao
# Processing Record 3 of Set 19 | karpathos
# Processing Record 4 of Set 19 | filadelfia
# Processing Record 5 of Set 19 | goderich
# Processing Record 6 of Set 19 | aykhal
# Processing Record 7 of Set 19 | severo-yeniseyskiy
# Processing Record 8 of Set 19 | kruisfontein
# Processing Record 9 of Set 19 | oktyabrskoye
# Processing Record 10 of Set 19 | narsaq
# Processing Record 11 of Set 19 | ahipara
# Processing Record 12 of Set 19 | sabha
# Processing Record 13 of Set 19 | innisfail
# Processing Record 14 of Set 19 | nouadhibou
# Processing Record 15 of Set 19 | jiaocheng
# Processing Record 16 of Set 19 | tromso
# Processing Record 17 of Set 19 | vao
# Processing Record 18 of Set 19 | kot putli
# City not found. Skipping...
# Processing Record 19 of Set 19 | flinders
# Processing Record 20 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 19 | yashan
# Processing Record 22 of Set 19 | olecko
# Processing Record 23 of Set 19 | purranque
# Processing Record 24 of Set 19 | isangel
# Processing Record 25 of Set 19 | hecun
# Processing Record 26 of Set 19 | verkhnevilyuysk
# Processing Record 27 of Set 19 | sankt polten
# Processing Record 28 of Set 19 | sola
# Processing Record 29 of Set 19 | lavrentiya
# Processing Record 30 of Set 19 | agogo
# Processing Record 31 of Set 19 | souris
# Processing Record 32 of Set 19 | rehoboth
# Processing Record 33 of Set 19 | marawi
# Processing Record 34 of Set 19 | pampa
# Processing Record 35 of Set 19 | lompoc
# Processing Record 36 of Set 19 | castro
# Processing Record 37 of Set 19 | unity
# Processing Record 38 of Set 19 | luderitz
# Processing Record 39 of Set 19 | carnarvon
# Processing Record 40 of Set 19 | arraial do cabo
# Processing Record 41 of Set 19 | geraldton
# Processing Record 42 of Set 19 | peniche
# Processing Record 43 of Set 19 | warrnambool
# Processing Record 44 of Set 19 | oriximina
# Processing Record 45 of Set 19 | zhigansk
# Processing Record 46 of Set 19 | shache
# Processing Record 47 of Set 19 | port macquarie
# Processing Record 48 of Set 19 | shenjiamen
# Processing Record 49 of Set 19 | chowchilla
# Processing Record 50 of Set 19 | grand-lahou
# Processing Record 1 of Set 20 | kahului
# Processing Record 2 of Set 20 | high level
# Processing Record 3 of Set 20 | ostrov
# Processing Record 4 of Set 20 | hue
# Processing Record 5 of Set 20 | sistranda
# Processing Record 6 of Set 20 | peleduy
# Processing Record 7 of Set 20 | bonavista
# Processing Record 8 of Set 20 | ulladulla
# Processing Record 9 of Set 20 | harper
# Processing Record 10 of Set 20 | guarapari
# Processing Record 11 of Set 20 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 20 | marsa matruh
# Processing Record 14 of Set 20 | puerto quijarro
# Processing Record 15 of Set 20 | kuah
# Processing Record 16 of Set 20 | saldanha
# Processing Record 17 of Set 20 | hambantota
# Processing Record 18 of Set 20 | kyren
# Processing Record 19 of Set 20 | paamiut
# Processing Record 20 of Set 20 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 20 | djibo
# Processing Record 22 of Set 20 | ende
# Processing Record 23 of Set 20 | necochea
# Processing Record 24 of Set 20 | winnemucca
# Processing Record 25 of Set 20 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 20 | lorengau
# Processing Record 27 of Set 20 | ponta delgada
# Processing Record 28 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 20 | yulara
# Processing Record 30 of Set 20 | karratha
# Processing Record 31 of Set 20 | lavumisa
# Processing Record 32 of Set 20 | souillac
# Processing Record 33 of Set 20 | lubao
# Processing Record 34 of Set 20 | edd
# Processing Record 35 of Set 20 | samandag
# Processing Record 36 of Set 20 | visnes
# Processing Record 37 of Set 20 | koslan
# Processing Record 38 of Set 20 | qaanaaq
# Processing Record 39 of Set 20 | hervey bay
# Processing Record 40 of Set 20 | tangjiazhuang
# Processing Record 41 of Set 20 | sterling
# Processing Record 42 of Set 20 | pierre
# Processing Record 43 of Set 20 | abadzekhskaya
# Processing Record 44 of Set 20 | nantucket
# Processing Record 45 of Set 20 | severo-kurilsk
# Processing Record 46 of Set 20 | makat
# Processing Record 47 of Set 20 | leningradskiy
# Processing Record 48 of Set 20 | sayyan
# Processing Record 49 of Set 20 | grand gaube
# Processing Record 50 of Set 20 | san pedro
# Processing Record 1 of Set 21 | coahuayana
# Processing Record 2 of Set 21 | whitehorse
# Processing Record 3 of Set 21 | glendive
# Processing Record 4 of Set 21 | cabo san lucas
# Processing Record 5 of Set 21 | torgau
# Processing Record 6 of Set 21 | tuy hoa
# Processing Record 7 of Set 21 | grindavik
# Processing Record 8 of Set 21 | nome
# Processing Record 9 of Set 21 | korla
# Processing Record 10 of Set 21 | junin
# Processing Record 11 of Set 21 | turukhansk
# Processing Record 12 of Set 21 | hofn
# Processing Record 13 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 21 | port hawkesbury
# Processing Record 15 of Set 21 | sao filipe
# Processing Record 16 of Set 21 | adamas
# Processing Record 17 of Set 21 | centralia
# Processing Record 18 of Set 21 | chicama
# Processing Record 19 of Set 21 | tchollire
# Processing Record 20 of Set 21 | high prairie
# Processing Record 21 of Set 21 | hollabrunn
# Processing Record 22 of Set 21 | ancud
# Processing Record 23 of Set 21 | olga
# Processing Record 24 of Set 21 | noshiro
# Processing Record 25 of Set 21 | komsomolskiy
# Processing Record 26 of Set 21 | uyemskiy
# Processing Record 27 of Set 21 | katobu
# Processing Record 28 of Set 21 | lebyazhye
# Processing Record 29 of Set 21 | nguru
# Processing Record 30 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 21 | boa vista
# Processing Record 32 of Set 21 | mackenzie
# Processing Record 33 of Set 21 | vangaindrano
# Processing Record 34 of Set 21 | tyukhtet
# Processing Record 35 of Set 21 | kalabo
# Processing Record 36 of Set 21 | linxia
# Processing Record 37 of Set 21 | anapskaya
# Processing Record 38 of Set 21 | carballo
# Processing Record 39 of Set 21 | inirida
# Processing Record 40 of Set 21 | novoshcherbinovskaya
# Processing Record 41 of Set 21 | sitka
# Processing Record 42 of Set 21 | donskoye
# Processing Record 43 of Set 21 | niteroi
# Processing Record 44 of Set 21 | javornik
# Processing Record 45 of Set 21 | chekhov
# Processing Record 46 of Set 21 | palembang
# Processing Record 47 of Set 21 | nikolskoye
# Processing Record 48 of Set 21 | shingu
# Processing Record 49 of Set 21 | tias
# Processing Record 50 of Set 21 | kavieng
# Processing Record 1 of Set 22 | makung
# City not found. Skipping...
# Processing Record 2 of Set 22 | sibolga
# Processing Record 3 of Set 22 | iqaluit
# Processing Record 4 of Set 22 | yate
# Processing Record 5 of Set 22 | sorland
# Processing Record 6 of Set 22 | garowe
# Processing Record 7 of Set 22 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 22 | tshikapa
# Processing Record 9 of Set 22 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 22 | morros
# Processing Record 11 of Set 22 | huarmey
# Processing Record 12 of Set 22 | the valley
# Processing Record 13 of Set 22 | alofi
# Processing Record 14 of Set 22 | kuzedeyevo
# Processing Record 15 of Set 22 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 22 | yunjinghong
# City not found. Skipping...
# Processing Record 17 of Set 22 | namatanai
# Processing Record 18 of Set 22 | srednekolymsk
# Processing Record 19 of Set 22 | hot springs
# Processing Record 20 of Set 22 | trairi
# Processing Record 21 of Set 22 | quebrangulo
# Processing Record 22 of Set 22 | beled
# Processing Record 23 of Set 22 | russell
# Processing Record 24 of Set 22 | pella
# Processing Record 25 of Set 22 | rennes
# Processing Record 26 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 22 | nicoya
# Processing Record 28 of Set 22 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 22 | tacuarembo
# Processing Record 30 of Set 22 | atambua
# Processing Record 31 of Set 22 | save
# Processing Record 32 of Set 22 | sao gabriel da cachoeira
# Processing Record 33 of Set 22 | bose
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qx/45cq96d10q5b2gsgz4xj8wzc0000gn/T/ipykernel_3933/2486836608.py in <module>
#      20     try:
#      21          # Parse the JSON and retreive data
# ---> 22         city_weather = requests.get(city_url).json()
#      23
#      24         # Parse out the needed data
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Convert to a Pandas DataFrame 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Bandarbeyla      SO   9.4942   50.8122     83.16        80
# 1              Dikson      RU  73.5069   80.5464     33.57        99
# 2                Goya      AR -29.1400  -59.2626     63.12        38
# 3        Jacareacanga      BR  -6.2222  -57.7528     84.45        77
# 4             Rikitea      PF -23.1203 -134.9692     76.80        71
# 5           Saskylakh      RU  71.9167  114.0833     34.09       100
# 6               Jumla      NP  29.2747   82.1838     57.13        74
# 7       Victor Harbor      AU -35.5667  138.6167     57.00        79
# 8          Georgetown      MY   5.4112  100.3354     82.33        94
# 9  Comodoro Rivadavia      AR -45.8667  -67.5000     53.46        43
#
#    Cloudiness  Wind Speed Weather Description
# 0           9       24.34           clear sky
# 1         100        8.55     overcast clouds
# 2           6       11.65           clear sky
# 3          99        4.63     overcast clouds
# 4         100       19.33     overcast clouds
# 5         100        7.25          light snow
# 6          67        3.71       broken clouds
# 7          33       14.07    scattered clouds
# 8          20        0.00          few clouds
# 9           0        2.30           clear sky

# %%
# Create the output file (CSV)
#output_data_file = "Weather_Database/updated_cities.csv"

# Export the City_Data into a CSV
#city_data_df.to_csv(output_data_file, index_label = "City_ID")
