# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations 
lats = np.random.uniform(90.000, -90.000, size = 2000)
lngs = np.random.uniform(180.000, -180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities= []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city to confirm sufficient count 
len(cities)
# Out:
# 760

# %%
# Importing weather API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Make an API call
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group the cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]

# %%
cities
# Out:
# ['mahebourg',
#  'huarmey',
#  'bredasdorp',
#  'nichinan',
#  'victoria',
#  'odweyne',
#  'saint-francois',
#  'letlhakeng',
#  'kavieng',
#  'coruripe',
#  'puerto ayora',
#  'port alfred',
#  'atuona',
#  'illoqqortoormiut',
#  'wanning',
#  'pangnirtung',
#  'vila franca do campo',
#  'port moresby',
#  'albany',
#  'chagda',
#  'bluff',
#  'mbuji-mayi',
#  'deputatskiy',
#  'chekhov',
#  'boromo',
#  'busselton',
#  'urucara',
#  'hilo',
#  'new norfolk',
#  'fortuna',
#  'severo-kurilsk',
#  'ponta do sol',
#  'hobart',
#  'tuktoyaktuk',
#  'ust-kishert',
#  'barrow',
#  'jamestown',
#  'pevek',
#  'carnarvon',
#  'saint-philippe',
#  'bengkulu',
#  'ahipara',
#  'cape town',
#  'sabzevar',
#  'upernavik',
#  'bonavista',
#  'rikitea',
#  'klaksvik',
#  'yellowknife',
#  'vaini',
#  'namibe',
#  'camocim',
#  'luena',
#  'jiblah',
#  'norman wells',
#  'byron bay',
#  'fairfield',
#  'hithadhoo',
#  'provideniya',
#  'qaanaaq',
#  'belushya guba',
#  'canon city',
#  'punta arenas',
#  'vilyuysk',
#  'lata',
#  'narsaq',
#  'mehamn',
#  'kaitangata',
#  'mar del plata',
#  'adrar',
#  'sao filipe',
#  'airai',
#  'biltine',
#  'north bend',
#  'college',
#  'ponta delgada',
#  'khatanga',
#  'ushuaia',
#  'ballina',
#  'angoche',
#  'nikolskoye',
#  'saskylakh',
#  'ulaanbaatar',
#  'leningradskiy',
#  'port macquarie',
#  'saint-gaudens',
#  'baran',
#  'cachoeira do sul',
#  'yulara',
#  'umzimvubu',
#  'barranca',
#  'ostrovnoy',
#  'mataura',
#  'karratha',
#  'port elizabeth',
#  'taolanaro',
#  'lebu',
#  'santa maria',
#  'iqaluit',
#  'tiksi',
#  'kununurra',
#  'kapaa',
#  'hermanus',
#  'geraldton',
#  'barentsburg',
#  'bathsheba',
#  'nisia floresta',
#  'preeceville',
#  'bambous virieux',
#  'san carlos del zulia',
#  'arraial do cabo',
#  'saint anthony',
#  'esperance',
#  'ixtapa',
#  'maldonado',
#  'castro',
#  'chumikan',
#  'menongue',
#  'quatre cocos',
#  'mount gambier',
#  'pacific grove',
#  'teguise',
#  'butaritari',
#  'umm lajj',
#  'kokopo',
#  'higuey',
#  'husavik',
#  'itapecerica',
#  'havre-saint-pierre',
#  'verkhnevilyuysk',
#  'georgetown',
#  'tuy hoa',
#  'rawson',
#  'cockburn town',
#  'zhangye',
#  'touros',
#  'pathein',
#  'filadelfia',
#  'sibolga',
#  'puerto montt',
#  'kodiak',
#  'kulhudhuffushi',
#  'grindavik',
#  'san patricio',
#  'xichang',
#  'nizhniy kuranakh',
#  'taburi',
#  'ola',
#  'pavilosta',
#  'ardahan',
#  'laguna',
#  'ketchikan',
#  'ormara',
#  'avarua',
#  'chokurdakh',
#  'kencong',
#  'cumaribo',
#  'sorland',
#  'bongaree',
#  'kumluca',
#  'dataganj',
#  'sao joao da barra',
#  'kraksaan',
#  'east london',
#  'souillac',
#  'saint-georges',
#  'te anau',
#  'faanui',
#  'hasaki',
#  'khorixas',
#  'chuy',
#  'codrington',
#  'warqla',
#  'mys shmidta',
#  'trinidad',
#  'busko-zdroj',
#  'tottori',
#  'kamloops',
#  'karpathos',
#  'san angelo',
#  'belaya gora',
#  'pisco',
#  'taldan',
#  'saleaula',
#  'jalingo',
#  'padang',
#  'brazzaville',
#  'acarau',
#  'zhigansk',
#  'penha',
#  'lagoa',
#  'brodnica',
#  'moranbah',
#  'bereda',
#  'meulaboh',
#  'port blair',
#  'cidreira',
#  'houma',
#  'flinders',
#  'galiwinku',
#  'alliston',
#  'talcahuano',
#  'alofi',
#  'talnakh',
#  'poya',
#  'petrovac',
#  'beysehir',
#  'sao joao dos patos',
#  'bintulu',
#  'homer',
#  'serowe',
#  'hamilton',
#  'garoua',
#  'lorengau',
#  'neiafu',
#  'matara',
#  'friesach',
#  'torbay',
#  'shunyi',
#  'diadi',
#  'omidiyeh',
#  'palmer',
#  'sentyabrskiy',
#  'vardo',
#  'kaspiysk',
#  'margate',
#  'attawapiskat',
#  'vermilion',
#  'samalaeulu',
#  'asau',
#  'vaitape',
#  'roald',
#  'porto torres',
#  'saint simons',
#  'buchanan',
#  'katsuura',
#  'bocaiuva',
#  'vanimo',
#  'plotnikovo',
#  'okha',
#  'kuche',
#  'rorvik',
#  'piacabucu',
#  'half moon bay',
#  'pawai',
#  'wageningen',
#  'tsihombe',
#  'shitanjing',
#  'grand river south east',
#  'belmonte',
#  'harper',
#  'henties bay',
#  'manacapuru',
#  'matane',
#  'batticaloa',
#  'eirunepe',
#  'constitucion',
#  'soyo',
#  'nouadhibou',
#  'sungaipenuh',
#  'malwan',
#  'pimenta bueno',
#  'quillota',
#  'kapoeta',
#  'raga',
#  'aklavik',
#  'srednekolymsk',
#  'kedrovyy',
#  'paamiut',
#  'leshukonskoye',
#  'gonen',
#  'dauphin',
#  'boa vista',
#  'bowen',
#  'nome',
#  'martapura',
#  'kidal',
#  'swan hill',
#  'yarega',
#  'kungurtug',
#  'marsa matruh',
#  'mudgee',
#  'rochegda',
#  'guajara-mirim',
#  'adre',
#  'amazar',
#  'payyannur',
#  'salihorsk',
#  'ribeira grande',
#  'shimoda',
#  'plouzane',
#  'togur',
#  'nizhneyansk',
#  'saint-joseph',
#  'sitka',
#  'meiganga',
#  'dehloran',
#  'kyshtovka',
#  'kavaratti',
#  'lexington',
#  'caninde',
#  'los llanos de aridane',
#  'cherskiy',
#  'khani',
#  'sisimiut',
#  'deep river',
#  'lubango',
#  'la gaulette',
#  'kosgi',
#  'mayumba',
#  'corinto',
#  'road town',
#  'dingle',
#  'omboue',
#  'natal',
#  'tres arroyos',
#  'cabinda',
#  'tarpon springs',
#  'bentiu',
#  'cubarral',
#  'vila',
#  'kargasok',
#  'dikson',
#  'tromso',
#  'temaraia',
#  'saint george',
#  'amderma',
#  'agadir',
#  'alyangula',
#  'solnechnyy',
#  'chapais',
#  'bairiki',
#  'maumere',
#  'velasco ibarra',
#  'semey',
#  'portland',
#  'umm kaddadah',
#  'vangaindrano',
#  'namatanai',
#  'amuntai',
#  'tasiilaq',
#  'kruisfontein',
#  'uusikaupunki',
#  'termiz',
#  'dunedin',
#  'lavrentiya',
#  'north myrtle beach',
#  'midland',
#  'la maddalena',
#  'den helder',
#  'abalak',
#  'coahuayana',
#  'urzhum',
#  'port hedland',
#  'san quintin',
#  'beringovskiy',
#  'pudozh',
#  'la fria',
#  'poronaysk',
#  'tapaua',
#  'tidore',
#  'midyat',
#  'bambanglipuro',
#  'shingu',
#  'aleppo',
#  'antofagasta',
#  'tura',
#  'hameenlinna',
#  'salinas',
#  'alice springs',
#  'hammerfest',
#  'ayan',
#  'chagoda',
#  'kahului',
#  'nguiu',
#  'rabo de peixe',
#  'rocha',
#  'kiunga',
#  'yumen',
#  'bethel',
#  'ekhabi',
#  'samusu',
#  'victoria point',
#  'mayor pablo lagerenza',
#  'manta',
#  'jomalig',
#  'siutu',
#  'wegorzewo',
#  'cayenne',
#  'komsomolskiy',
#  'ye',
#  'wanaka',
#  'vestmannaeyjar',
#  'cornwall',
#  'itoman',
#  'tocopilla',
#  'taltal',
#  'tuatapere',
#  'lakes entrance',
#  'severo-yeniseyskiy',
#  'guerrero negro',
#  'oranjemund',
#  'yaan',
#  'marawi',
#  'morehead',
#  'oudtshoorn',
#  'tumannyy',
#  'pytalovo',
#  'jega',
#  'sao luis de montes belos',
#  'pangody',
#  'kerman',
#  'itaituba',
#  'zeya',
#  'burnie',
#  'nadym',
#  'vostok',
#  'cabo san lucas',
#  'san juan',
#  'kisesa',
#  'omis',
#  'luderitz',
#  'ugoofaaru',
#  'celestun',
#  'batagay-alyta',
#  'thompson',
#  'bandarbeyla',
#  'nanortalik',
#  'emerald',
#  'ilebo',
#  'inuvik',
#  'hami',
#  'along',
#  'weihe',
#  'chiang kham',
#  'kracheh',
#  'ilhabela',
#  'le port',
#  'la asuncion',
#  'crab hill',
#  'surt',
#  'pangoa',
#  'bur gabo',
#  'sao gabriel da cachoeira',
#  'isiro',
#  'jujuy',
#  'bubaque',
#  'rio gallegos',
#  'mayo',
#  'marfino',
#  'santa cruz del sur',
#  'san cristobal',
#  'puerto leguizamo',
#  'matadi',
#  'aberdeen',
#  'nagorsk',
#  'kutum',
#  'molo',
#  'liwale',
#  'gat',
#  'ilulissat',
#  'zachary',
#  'lolua',
#  'ucluelet',
#  'sola',
#  'pemba',
#  'gannan',
#  'catia la mar',
#  'ayer itam',
#  'kim',
#  'rio grande',
#  'horki',
#  'owando',
#  'acapulco',
#  'sataua',
#  'brae',
#  'kalmunai',
#  'belfast',
#  'harboore',
#  'ipameri',
#  'uige',
#  'reconquista',
#  'totma',
#  'cotonou',
#  'kallaste',
#  'tarudant',
#  'dwarka',
#  'zharkent',
#  'foumban',
#  'ndele',
#  'basco',
#  'hokitika',
#  'minab',
#  'luza',
#  'turan',
#  'najran',
#  'araouane',
#  'port keats',
#  'udachnyy',
#  'ishigaki',
#  'waddan',
#  'mount clemens',
#  'kindu',
#  'ancud',
#  'sambava',
#  'qingan',
#  'usinsk',
#  'waipawa',
#  'tolga',
#  'tabialan',
#  'alibag',
#  'kamien pomorski',
#  'pustoshka',
#  'ivankiv',
#  'mao',
#  'nouakchott',
#  'riyadh',
#  'port lincoln',
#  'huilong',
#  'barcelos',
#  'longyearbyen',
#  'saldanha',
#  'broken hill',
#  'kuching',
#  'port hardy',
#  'mocajuba',
#  'yialos',
#  'igarka',
#  'mikuni',
#  'hurghada',
#  'zuwarah',
#  'merauke',
#  'businga',
#  'lompoc',
#  'hambantota',
#  'kabanjahe',
#  'tignere',
#  'bolungarvik',
#  'tandil',
#  'nyurba',
#  'kolda',
#  'vung tau',
#  'juneau',
#  'iracoubo',
#  'thinadhoo',
#  'zolotinka',
#  'maryborough',
#  'koslan',
#  'khandyga',
#  'mangan',
#  'kotelnikovo',
#  'karaul',
#  'envira',
#  'camacha',
#  'kibala',
#  'yanchukan',
#  'at-bashi',
#  'isangel',
#  'fairbanks',
#  'hirara',
#  'tautira',
#  'pampa',
#  'marcona',
#  'nakamura',
#  'paradwip',
#  'kholtoson',
#  'coquimbo',
#  'paray-le-monial',
#  'lahaina',
#  'ati',
#  'muyezerskiy',
#  'jieshi',
#  'hadrut',
#  'petropavlovsk-kamchatskiy',
#  'durres',
#  'krasnoznamensk',
#  'fort nelson',
#  'praia da vitoria',
#  'mnogovershinnyy',
#  'rundu',
#  'salalah',
#  'shevchenkove',
#  'miri',
#  'winslow',
#  'yerbogachen',
#  'venezuela',
#  'andenes',
#  'vao',
#  'kamenka',
#  'karamea',
#  'podbelsk',
#  'hendijan',
#  'sumkino',
#  'olafsvik',
#  'casas grandes',
#  'nelson bay',
#  'songea',
#  'armidale',
#  'san jose',
#  'paytug',
#  'xining',
#  'clyde river',
#  'richards bay',
#  'iwanai',
#  'kanniyakumari',
#  'skagastrond',
#  'aswan',
#  'rock springs',
#  'banepa',
#  'muswellbrook',
#  'wulanhaote',
#  'zakamensk',
#  'fort saint john',
#  'marzuq',
#  'belen',
#  'yar-sale',
#  'mahina',
#  'arlit',
#  'gorno-chuyskiy',
#  'vaitupu',
#  'sosnovo-ozerskoye',
#  'havelock',
#  'sur',
#  'chernyshevskiy',
#  'lyubim',
#  'isla mujeres',
#  'yenagoa',
#  'tabuk',
#  'morro bay',
#  'mossendjo',
#  'mirnyy',
#  'baglung',
#  'rambha',
#  'aksu',
#  'turka',
#  'hodmezovasarhely',
#  'gondanglegi',
#  'mrirt',
#  'teahupoo',
#  'kieta',
#  'khurai',
#  'palestina',
#  'bull savanna',
#  'grand haven',
#  'cururupu',
#  'tazovskiy',
#  'warrington',
#  'manutuke',
#  'ostashkov',
#  'el higo',
#  'northam',
#  'moratuwa',
#  'las palmas',
#  'privodino',
#  'spearfish',
#  'palu',
#  'kirensk',
#  'kampene',
#  'mitsamiouli',
#  'guantanamo',
#  'othonoi',
#  'aloleng',
#  'prince rupert',
#  'otaru',
#  'payakumbuh',
#  'susa',
#  'soe',
#  'wagar',
#  'luganville',
#  'okhotsk',
#  'keskin',
#  'dimona',
#  'atocha',
#  'gushikawa',
#  'tabiauea',
#  'achinsk',
#  'goderich',
#  'borova',
#  'borujan',
#  'tinqueux',
#  'moen',
#  'tucuman',
#  'labuhan',
#  'porto belo',
#  'putina',
#  'freeport',
#  'nishihara',
#  'guaruja',
#  'dalbandin',
#  'mahon',
#  'baykit',
#  'murighiol',
#  'falealupo',
#  'trairi',
#  'chissamba',
#  'tosno',
#  'fredericton',
#  'anar darreh',
#  'berlevag',
#  'alexandria',
#  'manokwari',
#  'yuanping',
#  'ende',
#  'avera',
#  'acari',
#  'surubim',
#  'victor harbor',
#  'ruatoria',
#  'charters towers',
#  'saint-leu',
#  'lamu',
#  'tabou',
#  'kuybyshevskiy zaton',
#  'georgiyevka',
#  'saint-marc',
#  'jambi',
#  'vila praia de ancora',
#  'gurgan',
#  'chapada dos guimaraes',
#  'puerto escondido',
#  'pringsewu',
#  'kadykchan',
#  'tsirguliina',
#  'kjopsvik',
#  'cache creek',
#  'luwuk',
#  'yanam',
#  'sakakah',
#  'sendriceni',
#  'flin flon',
#  'carutapera',
#  'pailon',
#  'hongan',
#  'beloha',
#  'lewiston',
#  'pareora',
#  'nabire',
#  'faya',
#  'tucupita',
#  'mangotsfield',
#  'sandviken',
#  'jales',
#  'doha',
#  'abnub',
#  'kainantu',
#  'miyako',
#  'vila velha',
#  'pitimbu',
#  'kennett',
#  'olinda',
#  'kudahuvadhoo',
#  'la ronge',
#  'atambua',
#  'tasbuget',
#  'krasnoarmeysk',
#  'ottobrunn',
#  'lucea',
#  'maromitsa',
#  'zamosc',
#  'kitob']

# %%
# Loop through all the cities in the list    
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
         # Parse the JSON and retreive data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H-%M-%S")
        
        # Append the city infomration into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description})
        
# If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping...")
        pass
    
# Indicate that Data Loading is Complete
print("--------------------------------")
print("Data Retreival Complete         ")
print("--------------------------------")
# Out:
# Processing Record 1 of Set 16 | mahebourg
# Processing Record 2 of Set 16 | huarmey
# Processing Record 3 of Set 16 | bredasdorp
# Processing Record 4 of Set 16 | nichinan
# Processing Record 5 of Set 16 | victoria
# Processing Record 6 of Set 16 | odweyne
# Processing Record 7 of Set 16 | saint-francois
# Processing Record 8 of Set 16 | letlhakeng
# Processing Record 9 of Set 16 | kavieng
# Processing Record 10 of Set 16 | coruripe
# Processing Record 11 of Set 16 | puerto ayora
# Processing Record 12 of Set 16 | port alfred
# Processing Record 13 of Set 16 | atuona
# Processing Record 14 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 16 | wanning
# Processing Record 16 of Set 16 | pangnirtung
# Processing Record 17 of Set 16 | vila franca do campo
# Processing Record 18 of Set 16 | port moresby
# Processing Record 19 of Set 16 | albany
# Processing Record 20 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 16 | bluff
# Processing Record 22 of Set 16 | mbuji-mayi
# Processing Record 23 of Set 16 | deputatskiy
# Processing Record 24 of Set 16 | chekhov
# Processing Record 25 of Set 16 | boromo
# Processing Record 26 of Set 16 | busselton
# Processing Record 27 of Set 16 | urucara
# Processing Record 28 of Set 16 | hilo
# Processing Record 29 of Set 16 | new norfolk
# Processing Record 30 of Set 16 | fortuna
# Processing Record 31 of Set 16 | severo-kurilsk
# Processing Record 32 of Set 16 | ponta do sol
# Processing Record 33 of Set 16 | hobart
# Processing Record 34 of Set 16 | tuktoyaktuk
# Processing Record 35 of Set 16 | ust-kishert
# Processing Record 36 of Set 16 | barrow
# Processing Record 37 of Set 16 | jamestown
# Processing Record 38 of Set 16 | pevek
# Processing Record 39 of Set 16 | carnarvon
# Processing Record 40 of Set 16 | saint-philippe
# Processing Record 41 of Set 16 | bengkulu
# Processing Record 42 of Set 16 | ahipara
# Processing Record 43 of Set 16 | cape town
# Processing Record 44 of Set 16 | sabzevar
# Processing Record 45 of Set 16 | upernavik
# Processing Record 46 of Set 16 | bonavista
# Processing Record 47 of Set 16 | rikitea
# Processing Record 48 of Set 16 | klaksvik
# Processing Record 49 of Set 16 | yellowknife
# Processing Record 50 of Set 16 | vaini
# Processing Record 1 of Set 17 | namibe
# Processing Record 2 of Set 17 | camocim
# Processing Record 3 of Set 17 | luena
# Processing Record 4 of Set 17 | jiblah
# Processing Record 5 of Set 17 | norman wells
# Processing Record 6 of Set 17 | byron bay
# Processing Record 7 of Set 17 | fairfield
# Processing Record 8 of Set 17 | hithadhoo
# Processing Record 9 of Set 17 | provideniya
# Processing Record 10 of Set 17 | qaanaaq
# Processing Record 11 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 17 | canon city
# Processing Record 13 of Set 17 | punta arenas
# Processing Record 14 of Set 17 | vilyuysk
# Processing Record 15 of Set 17 | lata
# Processing Record 16 of Set 17 | narsaq
# Processing Record 17 of Set 17 | mehamn
# Processing Record 18 of Set 17 | kaitangata
# Processing Record 19 of Set 17 | mar del plata
# Processing Record 20 of Set 17 | adrar
# Processing Record 21 of Set 17 | sao filipe
# Processing Record 22 of Set 17 | airai
# Processing Record 23 of Set 17 | biltine
# Processing Record 24 of Set 17 | north bend
# Processing Record 25 of Set 17 | college
# Processing Record 26 of Set 17 | ponta delgada
# Processing Record 27 of Set 17 | khatanga
# Processing Record 28 of Set 17 | ushuaia
# Processing Record 29 of Set 17 | ballina
# Processing Record 30 of Set 17 | angoche
# Processing Record 31 of Set 17 | nikolskoye
# Processing Record 32 of Set 17 | saskylakh
# Processing Record 33 of Set 17 | ulaanbaatar
# Processing Record 34 of Set 17 | leningradskiy
# Processing Record 35 of Set 17 | port macquarie
# Processing Record 36 of Set 17 | saint-gaudens
# Processing Record 37 of Set 17 | baran
# Processing Record 38 of Set 17 | cachoeira do sul
# Processing Record 39 of Set 17 | yulara
# Processing Record 40 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 17 | barranca
# Processing Record 42 of Set 17 | ostrovnoy
# Processing Record 43 of Set 17 | mataura
# Processing Record 44 of Set 17 | karratha
# Processing Record 45 of Set 17 | port elizabeth
# Processing Record 46 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 17 | lebu
# Processing Record 48 of Set 17 | santa maria
# Processing Record 49 of Set 17 | iqaluit
# Processing Record 50 of Set 17 | tiksi
# Processing Record 1 of Set 18 | kununurra
# Processing Record 2 of Set 18 | kapaa
# Processing Record 3 of Set 18 | hermanus
# Processing Record 4 of Set 18 | geraldton
# Processing Record 5 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 18 | bathsheba
# Processing Record 7 of Set 18 | nisia floresta
# Processing Record 8 of Set 18 | preeceville
# Processing Record 9 of Set 18 | bambous virieux
# Processing Record 10 of Set 18 | san carlos del zulia
# Processing Record 11 of Set 18 | arraial do cabo
# Processing Record 12 of Set 18 | saint anthony
# Processing Record 13 of Set 18 | esperance
# Processing Record 14 of Set 18 | ixtapa
# Processing Record 15 of Set 18 | maldonado
# Processing Record 16 of Set 18 | castro
# Processing Record 17 of Set 18 | chumikan
# Processing Record 18 of Set 18 | menongue
# Processing Record 19 of Set 18 | quatre cocos
# Processing Record 20 of Set 18 | mount gambier
# Processing Record 21 of Set 18 | pacific grove
# Processing Record 22 of Set 18 | teguise
# Processing Record 23 of Set 18 | butaritari
# Processing Record 24 of Set 18 | umm lajj
# Processing Record 25 of Set 18 | kokopo
# Processing Record 26 of Set 18 | higuey
# City not found. Skipping...
# Processing Record 27 of Set 18 | husavik
# Processing Record 28 of Set 18 | itapecerica
# Processing Record 29 of Set 18 | havre-saint-pierre
# Processing Record 30 of Set 18 | verkhnevilyuysk
# Processing Record 31 of Set 18 | georgetown
# Processing Record 32 of Set 18 | tuy hoa
# Processing Record 33 of Set 18 | rawson
# Processing Record 34 of Set 18 | cockburn town
# Processing Record 35 of Set 18 | zhangye
# Processing Record 36 of Set 18 | touros
# Processing Record 37 of Set 18 | pathein
# Processing Record 38 of Set 18 | filadelfia
# Processing Record 39 of Set 18 | sibolga
# Processing Record 40 of Set 18 | puerto montt
# Processing Record 41 of Set 18 | kodiak
# Processing Record 42 of Set 18 | kulhudhuffushi
# Processing Record 43 of Set 18 | grindavik
# Processing Record 44 of Set 18 | san patricio
# Processing Record 45 of Set 18 | xichang
# Processing Record 46 of Set 18 | nizhniy kuranakh
# Processing Record 47 of Set 18 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 18 | ola
# Processing Record 49 of Set 18 | pavilosta
# Processing Record 50 of Set 18 | ardahan
# Processing Record 1 of Set 19 | laguna
# Processing Record 2 of Set 19 | ketchikan
# Processing Record 3 of Set 19 | ormara
# Processing Record 4 of Set 19 | avarua
# Processing Record 5 of Set 19 | chokurdakh
# Processing Record 6 of Set 19 | kencong
# Processing Record 7 of Set 19 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 19 | sorland
# Processing Record 9 of Set 19 | bongaree
# Processing Record 10 of Set 19 | kumluca
# Processing Record 11 of Set 19 | dataganj
# Processing Record 12 of Set 19 | sao joao da barra
# Processing Record 13 of Set 19 | kraksaan
# Processing Record 14 of Set 19 | east london
# Processing Record 15 of Set 19 | souillac
# Processing Record 16 of Set 19 | saint-georges
# Processing Record 17 of Set 19 | te anau
# Processing Record 18 of Set 19 | faanui
# Processing Record 19 of Set 19 | hasaki
# Processing Record 20 of Set 19 | khorixas
# Processing Record 21 of Set 19 | chuy
# Processing Record 22 of Set 19 | codrington
# Processing Record 23 of Set 19 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 19 | trinidad
# Processing Record 26 of Set 19 | busko-zdroj
# Processing Record 27 of Set 19 | tottori
# Processing Record 28 of Set 19 | kamloops
# Processing Record 29 of Set 19 | karpathos
# Processing Record 30 of Set 19 | san angelo
# Processing Record 31 of Set 19 | belaya gora
# Processing Record 32 of Set 19 | pisco
# Processing Record 33 of Set 19 | taldan
# Processing Record 34 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 19 | jalingo
# Processing Record 36 of Set 19 | padang
# Processing Record 37 of Set 19 | brazzaville
# Processing Record 38 of Set 19 | acarau
# Processing Record 39 of Set 19 | zhigansk
# Processing Record 40 of Set 19 | penha
# Processing Record 41 of Set 19 | lagoa
# Processing Record 42 of Set 19 | brodnica
# Processing Record 43 of Set 19 | moranbah
# Processing Record 44 of Set 19 | bereda
# Processing Record 45 of Set 19 | meulaboh
# Processing Record 46 of Set 19 | port blair
# Processing Record 47 of Set 19 | cidreira
# Processing Record 48 of Set 19 | houma
# Processing Record 49 of Set 19 | flinders
# Processing Record 50 of Set 19 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 20 | alliston
# Processing Record 2 of Set 20 | talcahuano
# Processing Record 3 of Set 20 | alofi
# Processing Record 4 of Set 20 | talnakh
# Processing Record 5 of Set 20 | poya
# Processing Record 6 of Set 20 | petrovac
# Processing Record 7 of Set 20 | beysehir
# Processing Record 8 of Set 20 | sao joao dos patos
# Processing Record 9 of Set 20 | bintulu
# Processing Record 10 of Set 20 | homer
# Processing Record 11 of Set 20 | serowe
# Processing Record 12 of Set 20 | hamilton
# Processing Record 13 of Set 20 | garoua
# Processing Record 14 of Set 20 | lorengau
# Processing Record 15 of Set 20 | neiafu
# Processing Record 16 of Set 20 | matara
# Processing Record 17 of Set 20 | friesach
# Processing Record 18 of Set 20 | torbay
# Processing Record 19 of Set 20 | shunyi
# Processing Record 20 of Set 20 | diadi
# Processing Record 21 of Set 20 | omidiyeh
# Processing Record 22 of Set 20 | palmer
# Processing Record 23 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 20 | vardo
# Processing Record 25 of Set 20 | kaspiysk
# Processing Record 26 of Set 20 | margate
# Processing Record 27 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 20 | vermilion
# Processing Record 29 of Set 20 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 20 | asau
# Processing Record 31 of Set 20 | vaitape
# Processing Record 32 of Set 20 | roald
# Processing Record 33 of Set 20 | porto torres
# Processing Record 34 of Set 20 | saint simons
# Processing Record 35 of Set 20 | buchanan
# Processing Record 36 of Set 20 | katsuura
# Processing Record 37 of Set 20 | bocaiuva
# Processing Record 38 of Set 20 | vanimo
# Processing Record 39 of Set 20 | plotnikovo
# Processing Record 40 of Set 20 | okha
# Processing Record 41 of Set 20 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 20 | rorvik
# Processing Record 43 of Set 20 | piacabucu
# Processing Record 44 of Set 20 | half moon bay
# Processing Record 45 of Set 20 | pawai
# Processing Record 46 of Set 20 | wageningen
# Processing Record 47 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 20 | shitanjing
# Processing Record 49 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 20 | belmonte
# Processing Record 1 of Set 21 | harper
# Processing Record 2 of Set 21 | henties bay
# Processing Record 3 of Set 21 | manacapuru
# Processing Record 4 of Set 21 | matane
# Processing Record 5 of Set 21 | batticaloa
# Processing Record 6 of Set 21 | eirunepe
# Processing Record 7 of Set 21 | constitucion
# Processing Record 8 of Set 21 | soyo
# Processing Record 9 of Set 21 | nouadhibou
# Processing Record 10 of Set 21 | sungaipenuh
# Processing Record 11 of Set 21 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 21 | pimenta bueno
# Processing Record 13 of Set 21 | quillota
# Processing Record 14 of Set 21 | kapoeta
# Processing Record 15 of Set 21 | raga
# Processing Record 16 of Set 21 | aklavik
# Processing Record 17 of Set 21 | srednekolymsk
# Processing Record 18 of Set 21 | kedrovyy
# Processing Record 19 of Set 21 | paamiut
# Processing Record 20 of Set 21 | leshukonskoye
# Processing Record 21 of Set 21 | gonen
# Processing Record 22 of Set 21 | dauphin
# Processing Record 23 of Set 21 | boa vista
# Processing Record 24 of Set 21 | bowen
# Processing Record 25 of Set 21 | nome
# Processing Record 26 of Set 21 | martapura
# Processing Record 27 of Set 21 | kidal
# Processing Record 28 of Set 21 | swan hill
# Processing Record 29 of Set 21 | yarega
# Processing Record 30 of Set 21 | kungurtug
# Processing Record 31 of Set 21 | marsa matruh
# Processing Record 32 of Set 21 | mudgee
# Processing Record 33 of Set 21 | rochegda
# Processing Record 34 of Set 21 | guajara-mirim
# City not found. Skipping...
# Processing Record 35 of Set 21 | adre
# Processing Record 36 of Set 21 | amazar
# Processing Record 37 of Set 21 | payyannur
# Processing Record 38 of Set 21 | salihorsk
# Processing Record 39 of Set 21 | ribeira grande
# Processing Record 40 of Set 21 | shimoda
# Processing Record 41 of Set 21 | plouzane
# Processing Record 42 of Set 21 | togur
# Processing Record 43 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 21 | saint-joseph
# Processing Record 45 of Set 21 | sitka
# Processing Record 46 of Set 21 | meiganga
# Processing Record 47 of Set 21 | dehloran
# Processing Record 48 of Set 21 | kyshtovka
# Processing Record 49 of Set 21 | kavaratti
# Processing Record 50 of Set 21 | lexington
# Processing Record 1 of Set 22 | caninde
# Processing Record 2 of Set 22 | los llanos de aridane
# Processing Record 3 of Set 22 | cherskiy
# Processing Record 4 of Set 22 | khani
# Processing Record 5 of Set 22 | sisimiut
# Processing Record 6 of Set 22 | deep river
# Processing Record 7 of Set 22 | lubango
# Processing Record 8 of Set 22 | la gaulette
# City not found. Skipping...
# Processing Record 9 of Set 22 | kosgi
# City not found. Skipping...
# Processing Record 10 of Set 22 | mayumba
# Processing Record 11 of Set 22 | corinto
# Processing Record 12 of Set 22 | road town
# Processing Record 13 of Set 22 | dingle
# Processing Record 14 of Set 22 | omboue
# Processing Record 15 of Set 22 | natal
# Processing Record 16 of Set 22 | tres arroyos
# Processing Record 17 of Set 22 | cabinda
# Processing Record 18 of Set 22 | tarpon springs
# Processing Record 19 of Set 22 | bentiu
# Processing Record 20 of Set 22 | cubarral
# Processing Record 21 of Set 22 | vila
# Processing Record 22 of Set 22 | kargasok
# Processing Record 23 of Set 22 | dikson
# Processing Record 24 of Set 22 | tromso
# Processing Record 25 of Set 22 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 22 | saint george
# Processing Record 27 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 22 | agadir
# Processing Record 29 of Set 22 | alyangula
# Processing Record 30 of Set 22 | solnechnyy
# Processing Record 31 of Set 22 | chapais
# Processing Record 32 of Set 22 | bairiki
# Processing Record 33 of Set 22 | maumere
# Processing Record 34 of Set 22 | velasco ibarra
# Processing Record 35 of Set 22 | semey
# Processing Record 36 of Set 22 | portland
# Processing Record 37 of Set 22 | umm kaddadah
# Processing Record 38 of Set 22 | vangaindrano
# Processing Record 39 of Set 22 | namatanai
# Processing Record 40 of Set 22 | amuntai
# Processing Record 41 of Set 22 | tasiilaq
# Processing Record 42 of Set 22 | kruisfontein
# Processing Record 43 of Set 22 | uusikaupunki
# Processing Record 44 of Set 22 | termiz
# Processing Record 45 of Set 22 | dunedin
# Processing Record 46 of Set 22 | lavrentiya
# Processing Record 47 of Set 22 | north myrtle beach
# Processing Record 48 of Set 22 | midland
# Processing Record 49 of Set 22 | la maddalena
# Processing Record 50 of Set 22 | den helder
# Processing Record 1 of Set 23 | abalak
# Processing Record 2 of Set 23 | coahuayana
# Processing Record 3 of Set 23 | urzhum
# Processing Record 4 of Set 23 | port hedland
# Processing Record 5 of Set 23 | san quintin
# Processing Record 6 of Set 23 | beringovskiy
# Processing Record 7 of Set 23 | pudozh
# Processing Record 8 of Set 23 | la fria
# Processing Record 9 of Set 23 | poronaysk
# Processing Record 10 of Set 23 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 23 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 23 | midyat
# Processing Record 13 of Set 23 | bambanglipuro
# Processing Record 14 of Set 23 | shingu
# Processing Record 15 of Set 23 | aleppo
# Processing Record 16 of Set 23 | antofagasta
# Processing Record 17 of Set 23 | tura
# Processing Record 18 of Set 23 | hameenlinna
# Processing Record 19 of Set 23 | salinas
# Processing Record 20 of Set 23 | alice springs
# Processing Record 21 of Set 23 | hammerfest
# Processing Record 22 of Set 23 | ayan
# Processing Record 23 of Set 23 | chagoda
# Processing Record 24 of Set 23 | kahului
# Processing Record 25 of Set 23 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 23 | rabo de peixe
# Processing Record 27 of Set 23 | rocha
# Processing Record 28 of Set 23 | kiunga
# Processing Record 29 of Set 23 | yumen
# Processing Record 30 of Set 23 | bethel
# Processing Record 31 of Set 23 | ekhabi
# Processing Record 32 of Set 23 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 23 | victoria point
# Processing Record 34 of Set 23 | mayor pablo lagerenza
# Processing Record 35 of Set 23 | manta
# Processing Record 36 of Set 23 | jomalig
# City not found. Skipping...
# Processing Record 37 of Set 23 | siutu
# City not found. Skipping...
# Processing Record 38 of Set 23 | wegorzewo
# Processing Record 39 of Set 23 | cayenne
# Processing Record 40 of Set 23 | komsomolskiy
# Processing Record 41 of Set 23 | ye
# City not found. Skipping...
# Processing Record 42 of Set 23 | wanaka
# Processing Record 43 of Set 23 | vestmannaeyjar
# Processing Record 44 of Set 23 | cornwall
# Processing Record 45 of Set 23 | itoman
# Processing Record 46 of Set 23 | tocopilla
# Processing Record 47 of Set 23 | taltal
# Processing Record 48 of Set 23 | tuatapere
# Processing Record 49 of Set 23 | lakes entrance
# Processing Record 50 of Set 23 | severo-yeniseyskiy
# Processing Record 1 of Set 24 | guerrero negro
# Processing Record 2 of Set 24 | oranjemund
# Processing Record 3 of Set 24 | yaan
# Processing Record 4 of Set 24 | marawi
# Processing Record 5 of Set 24 | morehead
# Processing Record 6 of Set 24 | oudtshoorn
# Processing Record 7 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 24 | pytalovo
# Processing Record 9 of Set 24 | jega
# Processing Record 10 of Set 24 | sao luis de montes belos
# Processing Record 11 of Set 24 | pangody
# Processing Record 12 of Set 24 | kerman
# Processing Record 13 of Set 24 | itaituba
# Processing Record 14 of Set 24 | zeya
# Processing Record 15 of Set 24 | burnie
# Processing Record 16 of Set 24 | nadym
# Processing Record 17 of Set 24 | vostok
# Processing Record 18 of Set 24 | cabo san lucas
# Processing Record 19 of Set 24 | san juan
# Processing Record 20 of Set 24 | kisesa
# Processing Record 21 of Set 24 | omis
# Processing Record 22 of Set 24 | luderitz
# Processing Record 23 of Set 24 | ugoofaaru
# Processing Record 24 of Set 24 | celestun
# Processing Record 25 of Set 24 | batagay-alyta
# Processing Record 26 of Set 24 | thompson
# Processing Record 27 of Set 24 | bandarbeyla
# Processing Record 28 of Set 24 | nanortalik
# Processing Record 29 of Set 24 | emerald
# Processing Record 30 of Set 24 | ilebo
# Processing Record 31 of Set 24 | inuvik
# Processing Record 32 of Set 24 | hami
# Processing Record 33 of Set 24 | along
# Processing Record 34 of Set 24 | weihe
# Processing Record 35 of Set 24 | chiang kham
# Processing Record 36 of Set 24 | kracheh
# City not found. Skipping...
# Processing Record 37 of Set 24 | ilhabela
# Processing Record 38 of Set 24 | le port
# Processing Record 39 of Set 24 | la asuncion
# Processing Record 40 of Set 24 | crab hill
# City not found. Skipping...
# Processing Record 41 of Set 24 | surt
# Processing Record 42 of Set 24 | pangoa
# Processing Record 43 of Set 24 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 24 | sao gabriel da cachoeira
# Processing Record 45 of Set 24 | isiro
# Processing Record 46 of Set 24 | jujuy
# City not found. Skipping...
# Processing Record 47 of Set 24 | bubaque
# Processing Record 48 of Set 24 | rio gallegos
# Processing Record 49 of Set 24 | mayo
# Processing Record 50 of Set 24 | marfino
# Processing Record 1 of Set 25 | santa cruz del sur
# Processing Record 2 of Set 25 | san cristobal
# Processing Record 3 of Set 25 | puerto leguizamo
# Processing Record 4 of Set 25 | matadi
# Processing Record 5 of Set 25 | aberdeen
# Processing Record 6 of Set 25 | nagorsk
# Processing Record 7 of Set 25 | kutum
# Processing Record 8 of Set 25 | molo
# Processing Record 9 of Set 25 | liwale
# Processing Record 10 of Set 25 | gat
# Processing Record 11 of Set 25 | ilulissat
# Processing Record 12 of Set 25 | zachary
# Processing Record 13 of Set 25 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 25 | ucluelet
# Processing Record 15 of Set 25 | sola
# Processing Record 16 of Set 25 | pemba
# Processing Record 17 of Set 25 | gannan
# Processing Record 18 of Set 25 | catia la mar
# Processing Record 19 of Set 25 | ayer itam
# City not found. Skipping...
# Processing Record 20 of Set 25 | kim
# Processing Record 21 of Set 25 | rio grande
# Processing Record 22 of Set 25 | horki
# Processing Record 23 of Set 25 | owando
# Processing Record 24 of Set 25 | acapulco
# Processing Record 25 of Set 25 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 25 | brae
# Processing Record 27 of Set 25 | kalmunai
# Processing Record 28 of Set 25 | belfast
# Processing Record 29 of Set 25 | harboore
# Processing Record 30 of Set 25 | ipameri
# Processing Record 31 of Set 25 | uige
# Processing Record 32 of Set 25 | reconquista
# Processing Record 33 of Set 25 | totma
# Processing Record 34 of Set 25 | cotonou
# Processing Record 35 of Set 25 | kallaste
# Processing Record 36 of Set 25 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 25 | dwarka
# Processing Record 38 of Set 25 | zharkent
# Processing Record 39 of Set 25 | foumban
# Processing Record 40 of Set 25 | ndele
# Processing Record 41 of Set 25 | basco
# Processing Record 42 of Set 25 | hokitika
# Processing Record 43 of Set 25 | minab
# Processing Record 44 of Set 25 | luza
# Processing Record 45 of Set 25 | turan
# Processing Record 46 of Set 25 | najran
# Processing Record 47 of Set 25 | araouane
# Processing Record 48 of Set 25 | port keats
# Processing Record 49 of Set 25 | udachnyy
# Processing Record 50 of Set 25 | ishigaki
# Processing Record 1 of Set 26 | waddan
# Processing Record 2 of Set 26 | mount clemens
# Processing Record 3 of Set 26 | kindu
# Processing Record 4 of Set 26 | ancud
# Processing Record 5 of Set 26 | sambava
# Processing Record 6 of Set 26 | qingan
# City not found. Skipping...
# Processing Record 7 of Set 26 | usinsk
# Processing Record 8 of Set 26 | waipawa
# Processing Record 9 of Set 26 | tolga
# Processing Record 10 of Set 26 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 26 | alibag
# Processing Record 12 of Set 26 | kamien pomorski
# Processing Record 13 of Set 26 | pustoshka
# Processing Record 14 of Set 26 | ivankiv
# Processing Record 15 of Set 26 | mao
# Processing Record 16 of Set 26 | nouakchott
# Processing Record 17 of Set 26 | riyadh
# Processing Record 18 of Set 26 | port lincoln
# Processing Record 19 of Set 26 | huilong
# Processing Record 20 of Set 26 | barcelos
# Processing Record 21 of Set 26 | longyearbyen
# Processing Record 22 of Set 26 | saldanha
# Processing Record 23 of Set 26 | broken hill
# Processing Record 24 of Set 26 | kuching
# Processing Record 25 of Set 26 | port hardy
# Processing Record 26 of Set 26 | mocajuba
# Processing Record 27 of Set 26 | yialos
# City not found. Skipping...
# Processing Record 28 of Set 26 | igarka
# Processing Record 29 of Set 26 | mikuni
# Processing Record 30 of Set 26 | hurghada
# Processing Record 31 of Set 26 | zuwarah
# Processing Record 32 of Set 26 | merauke
# Processing Record 33 of Set 26 | businga
# Processing Record 34 of Set 26 | lompoc
# Processing Record 35 of Set 26 | hambantota
# Processing Record 36 of Set 26 | kabanjahe
# Processing Record 37 of Set 26 | tignere
# Processing Record 38 of Set 26 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 26 | tandil
# Processing Record 40 of Set 26 | nyurba
# Processing Record 41 of Set 26 | kolda
# Processing Record 42 of Set 26 | vung tau
# Processing Record 43 of Set 26 | juneau
# Processing Record 44 of Set 26 | iracoubo
# Processing Record 45 of Set 26 | thinadhoo
# Processing Record 46 of Set 26 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 26 | maryborough
# Processing Record 48 of Set 26 | koslan
# Processing Record 49 of Set 26 | khandyga
# Processing Record 50 of Set 26 | mangan
# Processing Record 1 of Set 27 | kotelnikovo
# Processing Record 2 of Set 27 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 27 | envira
# Processing Record 4 of Set 27 | camacha
# Processing Record 5 of Set 27 | kibala
# Processing Record 6 of Set 27 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 27 | at-bashi
# Processing Record 8 of Set 27 | isangel
# Processing Record 9 of Set 27 | fairbanks
# Processing Record 10 of Set 27 | hirara
# Processing Record 11 of Set 27 | tautira
# Processing Record 12 of Set 27 | pampa
# Processing Record 13 of Set 27 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 27 | nakamura
# Processing Record 15 of Set 27 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 27 | kholtoson
# Processing Record 17 of Set 27 | coquimbo
# Processing Record 18 of Set 27 | paray-le-monial
# Processing Record 19 of Set 27 | lahaina
# Processing Record 20 of Set 27 | ati
# Processing Record 21 of Set 27 | muyezerskiy
# Processing Record 22 of Set 27 | jieshi
# Processing Record 23 of Set 27 | hadrut
# Processing Record 24 of Set 27 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 27 | durres
# Processing Record 26 of Set 27 | krasnoznamensk
# Processing Record 27 of Set 27 | fort nelson
# Processing Record 28 of Set 27 | praia da vitoria
# Processing Record 29 of Set 27 | mnogovershinnyy
# Processing Record 30 of Set 27 | rundu
# Processing Record 31 of Set 27 | salalah
# Processing Record 32 of Set 27 | shevchenkove
# Processing Record 33 of Set 27 | miri
# Processing Record 34 of Set 27 | winslow
# Processing Record 35 of Set 27 | yerbogachen
# Processing Record 36 of Set 27 | venezuela
# Processing Record 37 of Set 27 | andenes
# Processing Record 38 of Set 27 | vao
# Processing Record 39 of Set 27 | kamenka
# Processing Record 40 of Set 27 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 27 | podbelsk
# City not found. Skipping...
# Processing Record 42 of Set 27 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 27 | sumkino
# Processing Record 44 of Set 27 | olafsvik
# Processing Record 45 of Set 27 | casas grandes
# Processing Record 46 of Set 27 | nelson bay
# Processing Record 47 of Set 27 | songea
# Processing Record 48 of Set 27 | armidale
# Processing Record 49 of Set 27 | san jose
# Processing Record 50 of Set 27 | paytug
# City not found. Skipping...
# Processing Record 1 of Set 28 | xining
# Processing Record 2 of Set 28 | clyde river
# Processing Record 3 of Set 28 | richards bay
# Processing Record 4 of Set 28 | iwanai
# Processing Record 5 of Set 28 | kanniyakumari
# Processing Record 6 of Set 28 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 28 | aswan
# Processing Record 8 of Set 28 | rock springs
# Processing Record 9 of Set 28 | banepa
# Processing Record 10 of Set 28 | muswellbrook
# Processing Record 11 of Set 28 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 28 | zakamensk
# Processing Record 13 of Set 28 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 28 | marzuq
# Processing Record 15 of Set 28 | belen
# Processing Record 16 of Set 28 | yar-sale
# Processing Record 17 of Set 28 | mahina
# Processing Record 18 of Set 28 | arlit
# Processing Record 19 of Set 28 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 28 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 28 | sosnovo-ozerskoye
# Processing Record 22 of Set 28 | havelock
# Processing Record 23 of Set 28 | sur
# Processing Record 24 of Set 28 | chernyshevskiy
# Processing Record 25 of Set 28 | lyubim
# Processing Record 26 of Set 28 | isla mujeres
# Processing Record 27 of Set 28 | yenagoa
# Processing Record 28 of Set 28 | tabuk
# Processing Record 29 of Set 28 | morro bay
# Processing Record 30 of Set 28 | mossendjo
# Processing Record 31 of Set 28 | mirnyy
# Processing Record 32 of Set 28 | baglung
# Processing Record 33 of Set 28 | rambha
# Processing Record 34 of Set 28 | aksu
# Processing Record 35 of Set 28 | turka
# Processing Record 36 of Set 28 | hodmezovasarhely
# Processing Record 37 of Set 28 | gondanglegi
# Processing Record 38 of Set 28 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 28 | teahupoo
# Processing Record 40 of Set 28 | kieta
# Processing Record 41 of Set 28 | khurai
# Processing Record 42 of Set 28 | palestina
# Processing Record 43 of Set 28 | bull savanna
# Processing Record 44 of Set 28 | grand haven
# Processing Record 45 of Set 28 | cururupu
# Processing Record 46 of Set 28 | tazovskiy
# Processing Record 47 of Set 28 | warrington
# Processing Record 48 of Set 28 | manutuke
# Processing Record 49 of Set 28 | ostashkov
# Processing Record 50 of Set 28 | el higo
# Processing Record 1 of Set 29 | northam
# Processing Record 2 of Set 29 | moratuwa
# Processing Record 3 of Set 29 | las palmas
# Processing Record 4 of Set 29 | privodino
# Processing Record 5 of Set 29 | spearfish
# Processing Record 6 of Set 29 | palu
# Processing Record 7 of Set 29 | kirensk
# Processing Record 8 of Set 29 | kampene
# Processing Record 9 of Set 29 | mitsamiouli
# Processing Record 10 of Set 29 | guantanamo
# Processing Record 11 of Set 29 | othonoi
# City not found. Skipping...
# Processing Record 12 of Set 29 | aloleng
# Processing Record 13 of Set 29 | prince rupert
# Processing Record 14 of Set 29 | otaru
# Processing Record 15 of Set 29 | payakumbuh
# Processing Record 16 of Set 29 | susa
# Processing Record 17 of Set 29 | soe
# Processing Record 18 of Set 29 | wagar
# Processing Record 19 of Set 29 | luganville
# Processing Record 20 of Set 29 | okhotsk
# Processing Record 21 of Set 29 | keskin
# Processing Record 22 of Set 29 | dimona
# Processing Record 23 of Set 29 | atocha
# Processing Record 24 of Set 29 | gushikawa
# Processing Record 25 of Set 29 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 29 | achinsk
# Processing Record 27 of Set 29 | goderich
# Processing Record 28 of Set 29 | borova
# Processing Record 29 of Set 29 | borujan
# City not found. Skipping...
# Processing Record 30 of Set 29 | tinqueux
# Processing Record 31 of Set 29 | moen
# Processing Record 32 of Set 29 | tucuman
# Processing Record 33 of Set 29 | labuhan
# Processing Record 34 of Set 29 | porto belo
# Processing Record 35 of Set 29 | putina
# Processing Record 36 of Set 29 | freeport
# Processing Record 37 of Set 29 | nishihara
# Processing Record 38 of Set 29 | guaruja
# Processing Record 39 of Set 29 | dalbandin
# Processing Record 40 of Set 29 | mahon
# Processing Record 41 of Set 29 | baykit
# Processing Record 42 of Set 29 | murighiol
# Processing Record 43 of Set 29 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 29 | trairi
# Processing Record 45 of Set 29 | chissamba
# Processing Record 46 of Set 29 | tosno
# Processing Record 47 of Set 29 | fredericton
# Processing Record 48 of Set 29 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 29 | berlevag
# Processing Record 50 of Set 29 | alexandria
# Processing Record 1 of Set 30 | manokwari
# Processing Record 2 of Set 30 | yuanping
# Processing Record 3 of Set 30 | ende
# Processing Record 4 of Set 30 | avera
# Processing Record 5 of Set 30 | acari
# Processing Record 6 of Set 30 | surubim
# Processing Record 7 of Set 30 | victor harbor
# Processing Record 8 of Set 30 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 30 | charters towers
# Processing Record 10 of Set 30 | saint-leu
# Processing Record 11 of Set 30 | lamu
# Processing Record 12 of Set 30 | tabou
# Processing Record 13 of Set 30 | kuybyshevskiy zaton
# Processing Record 14 of Set 30 | georgiyevka
# Processing Record 15 of Set 30 | saint-marc
# Processing Record 16 of Set 30 | jambi
# Processing Record 17 of Set 30 | vila praia de ancora
# Processing Record 18 of Set 30 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 30 | chapada dos guimaraes
# Processing Record 20 of Set 30 | puerto escondido
# Processing Record 21 of Set 30 | pringsewu
# Processing Record 22 of Set 30 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 30 | tsirguliina
# Processing Record 24 of Set 30 | kjopsvik
# Processing Record 25 of Set 30 | cache creek
# Processing Record 26 of Set 30 | luwuk
# Processing Record 27 of Set 30 | yanam
# Processing Record 28 of Set 30 | sakakah
# Processing Record 29 of Set 30 | sendriceni
# Processing Record 30 of Set 30 | flin flon
# Processing Record 31 of Set 30 | carutapera
# Processing Record 32 of Set 30 | pailon
# Processing Record 33 of Set 30 | hongan
# City not found. Skipping...
# Processing Record 34 of Set 30 | beloha
# Processing Record 35 of Set 30 | lewiston
# Processing Record 36 of Set 30 | pareora
# Processing Record 37 of Set 30 | nabire
# Processing Record 38 of Set 30 | faya
# Processing Record 39 of Set 30 | tucupita
# Processing Record 40 of Set 30 | mangotsfield
# Processing Record 41 of Set 30 | sandviken
# Processing Record 42 of Set 30 | jales
# Processing Record 43 of Set 30 | doha
# Processing Record 44 of Set 30 | abnub
# Processing Record 45 of Set 30 | kainantu
# Processing Record 46 of Set 30 | miyako
# Processing Record 47 of Set 30 | vila velha
# Processing Record 48 of Set 30 | pitimbu
# Processing Record 49 of Set 30 | kennett
# Processing Record 50 of Set 30 | olinda
# Processing Record 1 of Set 31 | kudahuvadhoo
# Processing Record 2 of Set 31 | la ronge
# Processing Record 3 of Set 31 | atambua
# Processing Record 4 of Set 31 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 31 | krasnoarmeysk
# Processing Record 6 of Set 31 | ottobrunn
# Processing Record 7 of Set 31 | lucea
# Processing Record 8 of Set 31 | maromitsa
# Processing Record 9 of Set 31 | zamosc
# Processing Record 10 of Set 31 | kitob
# --------------------------------
# Data Retreival Complete
# --------------------------------

# %%
# Convert to a Pandas DataFrame 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg      MU -20.4081   57.7000     73.69        88          20
# 1         Huarmey      PE -10.0681  -78.1522     66.94        76          50
# 2      Bredasdorp      ZA -34.5322   20.0403     62.56        72           0
# 3        Nichinan      JP  31.6000  131.3667     56.73        85         100
# 4        Victoria      HK  22.2855  114.1577     71.94        94         100
# 5         Odweyne      SO   9.4092   45.0640     90.07        16          17
# 6  Saint-Francois      FR  46.4154    3.9054     74.64        57          75
# 7      Letlhakeng      BW -24.0944   25.0298     77.95        22          53
# 8         Kavieng      PG  -2.5744  150.7967     81.21        73         100
# 9        Coruripe      BR -10.1256  -36.1756     81.64        77         100
#
#    Wind Speed Weather Description
# 0        6.91          few clouds
# 1        7.05    scattered clouds
# 2       10.31           clear sky
# 3        2.73          light rain
# 4       15.99     overcast clouds
# 5        3.15          few clouds
# 6        6.91       broken clouds
# 7        8.70       broken clouds
# 8        6.13     overcast clouds
# 9       10.25     overcast clouds

# %%
# Create the output file (CSV)
#output_data_file = "Weather_Database/updated_cities.csv"

# Export the City_Data into a CSV
#city_data_df.to_csv(output_data_file, index_label = "City_ID")
